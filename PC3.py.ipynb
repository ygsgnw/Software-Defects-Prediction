# %%
from scipy.io import arff
import pandas as pd
import numpy as np
import math

from numpy import unique
from numpy import where
from matplotlib import pyplot

data = arff.loadarff('./DefectData-master/DefectData/inst/extdata/terapromise/mccabe/PC3.arff') 
df = pd.DataFrame(data[0])

# %%
df.shape
# Out:
# (1077, 38)

# %%
df.head()
# Out:
#    LOC_BLANK  BRANCH_COUNT  CALL_PAIRS  LOC_CODE_AND_COMMENT  LOC_COMMENTS  \
# 0       16.0          13.0         1.0                   6.0          11.0
# 1        2.0           7.0         0.0                   0.0           7.0
# 2        1.0          13.0         5.0                   0.0           0.0
# 3        8.0           3.0         1.0                   0.0           1.0
# 4        1.0           5.0         2.0                   1.0           1.0
#
#    CONDITION_COUNT  CYCLOMATIC_COMPLEXITY  CYCLOMATIC_DENSITY  DECISION_COUNT  \
# 0             20.0                    7.0                0.24             8.0
# 1             10.0                    4.0                0.29             4.0
# 2             22.0                    7.0                0.37            10.0
# 3              4.0                    2.0                0.14             2.0
# 4              6.0                    3.0                0.15             2.0
#
#    DECISION_DENSITY  ...  NODE_COUNT  NORMALIZED_CYLOMATIC_COMPLEXITY  \
# 0               2.5  ...        17.0                             0.12
# 1               2.5  ...         9.0                             0.17
# 2               2.2  ...        23.0                             0.33
# 3               2.0  ...         6.0                             0.08
# 4               3.0  ...         9.0                             0.13
#
#    NUM_OPERANDS  NUM_OPERATORS  NUM_UNIQUE_OPERANDS  NUM_UNIQUE_OPERATORS  \
# 0          68.0           81.0                 31.0                  21.0
# 1           9.0           22.0                  5.0                   8.0
# 2          38.0           53.0                 19.0                  19.0
# 3          32.0           38.0                 19.0                  13.0
# 4          27.0           33.0                 19.0                  14.0
#
#    NUMBER_OF_LINES  PERCENT_COMMENTS  LOC_TOTAL  Defective
# 0             57.0             42.50       29.0       b'N'
# 1             24.0             33.33       14.0       b'Y'
# 2             21.0              0.00       19.0       b'N'
# 3             24.0              6.67       14.0       b'N'
# 4             23.0              9.52       20.0       b'N'
#
# [5 rows x 38 columns]

# %%
x = df.drop(['Defective'],axis = 'columns')
x.head()
# Out:
#    LOC_BLANK  BRANCH_COUNT  CALL_PAIRS  LOC_CODE_AND_COMMENT  LOC_COMMENTS  \
# 0       16.0          13.0         1.0                   6.0          11.0
# 1        2.0           7.0         0.0                   0.0           7.0
# 2        1.0          13.0         5.0                   0.0           0.0
# 3        8.0           3.0         1.0                   0.0           1.0
# 4        1.0           5.0         2.0                   1.0           1.0
#
#    CONDITION_COUNT  CYCLOMATIC_COMPLEXITY  CYCLOMATIC_DENSITY  DECISION_COUNT  \
# 0             20.0                    7.0                0.24             8.0
# 1             10.0                    4.0                0.29             4.0
# 2             22.0                    7.0                0.37            10.0
# 3              4.0                    2.0                0.14             2.0
# 4              6.0                    3.0                0.15             2.0
#
#    DECISION_DENSITY  ...  MULTIPLE_CONDITION_COUNT  NODE_COUNT  \
# 0               2.5  ...                      10.0        17.0
# 1               2.5  ...                       5.0         9.0
# 2               2.2  ...                      11.0        23.0
# 3               2.0  ...                       2.0         6.0
# 4               3.0  ...                       3.0         9.0
#
#    NORMALIZED_CYLOMATIC_COMPLEXITY  NUM_OPERANDS  NUM_OPERATORS  \
# 0                             0.12          68.0           81.0
# 1                             0.17           9.0           22.0
# 2                             0.33          38.0           53.0
# 3                             0.08          32.0           38.0
# 4                             0.13          27.0           33.0
#
#    NUM_UNIQUE_OPERANDS  NUM_UNIQUE_OPERATORS  NUMBER_OF_LINES  \
# 0                 31.0                  21.0             57.0
# 1                  5.0                   8.0             24.0
# 2                 19.0                  19.0             21.0
# 3                 19.0                  13.0             24.0
# 4                 19.0                  14.0             23.0
#
#    PERCENT_COMMENTS  LOC_TOTAL
# 0             42.50       29.0
# 1             33.33       14.0
# 2              0.00       19.0
# 3              6.67       14.0
# 4              9.52       20.0
#
# [5 rows x 37 columns]

# %%
buggy = b'Y'
clean = b'N'

df.Defective[df.Defective == buggy] = 0
df.Defective[df.Defective == clean] = 1

df['Defective'].astype(object).astype(int)

y = df['Defective']
y = y.astype(int)
y.head()
# Out:
# C:\Users\Hp\AppData\Local\Temp/ipykernel_3384/3280558783.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Defective[df.Defective == buggy] = 0
# C:\Users\Hp\AppData\Local\Temp/ipykernel_3384/3280558783.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Defective[df.Defective == clean] = 1
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Defective, dtype: int32

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

model = LogisticRegression()
rfe = RFE(model)
fit = rfe.fit(x,y)

fit.support_

selected = list(fit.support_)
selected
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False]

# %%
columns_names = df.columns.values.tolist()
columns_names
# Out:
# ['LOC_BLANK',
#  'BRANCH_COUNT',
#  'CALL_PAIRS',
#  'LOC_CODE_AND_COMMENT',
#  'LOC_COMMENTS',
#  'CONDITION_COUNT',
#  'CYCLOMATIC_COMPLEXITY',
#  'CYCLOMATIC_DENSITY',
#  'DECISION_COUNT',
#  'DECISION_DENSITY',
#  'DESIGN_COMPLEXITY',
#  'DESIGN_DENSITY',
#  'EDGE_COUNT',
#  'ESSENTIAL_COMPLEXITY',
#  'ESSENTIAL_DENSITY',
#  'LOC_EXECUTABLE',
#  'PARAMETER_COUNT',
#  'HALSTEAD_CONTENT',
#  'HALSTEAD_DIFFICULTY',
#  'HALSTEAD_EFFORT',
#  'HALSTEAD_ERROR_EST',
#  'HALSTEAD_LENGTH',
#  'HALSTEAD_LEVEL',
#  'HALSTEAD_PROG_TIME',
#  'HALSTEAD_VOLUME',
#  'MAINTENANCE_SEVERITY',
#  'MODIFIED_CONDITION_COUNT',
#  'MULTIPLE_CONDITION_COUNT',
#  'NODE_COUNT',
#  'NORMALIZED_CYLOMATIC_COMPLEXITY',
#  'NUM_OPERANDS',
#  'NUM_OPERATORS',
#  'NUM_UNIQUE_OPERANDS',
#  'NUM_UNIQUE_OPERATORS',
#  'NUMBER_OF_LINES',
#  'PERCENT_COMMENTS',
#  'LOC_TOTAL',
#  'Defective']

# %%
print(len(columns_names))
print(len(selected))
# Out:
# 38
# 37

# %%
for i in range(37):
    if selected[i] == False:
        df = df.drop([columns_names[i]], axis = 'columns')
        
df.head()
# Out:
#    LOC_BLANK  CYCLOMATIC_DENSITY  DECISION_COUNT  DECISION_DENSITY  \
# 0       16.0                0.24             8.0               2.5
# 1        2.0                0.29             4.0               2.5
# 2        1.0                0.37            10.0               2.2
# 3        8.0                0.14             2.0               2.0
# 4        1.0                0.15             2.0               3.0
#
#    DESIGN_DENSITY  EDGE_COUNT  ESSENTIAL_COMPLEXITY  LOC_EXECUTABLE  \
# 0            0.43        22.0                   6.0            23.0
# 1            0.25        11.0                   4.0            14.0
# 2            0.57        28.0                   7.0            19.0
# 3            1.00         6.0                   1.0            14.0
# 4            0.67        10.0                   3.0            19.0
#
#    PARAMETER_COUNT  HALSTEAD_CONTENT  HALSTEAD_DIFFICULTY  HALSTEAD_LENGTH  \
# 0              0.0             36.88                23.03            149.0
# 1              0.0             15.93                 7.20             31.0
# 2              1.0             25.13                19.00             91.0
# 3              1.0             31.97                10.95             70.0
# 4              1.0             30.43                 9.95             60.0
#
#    MAINTENANCE_SEVERITY  MULTIPLE_CONDITION_COUNT  NODE_COUNT  NUM_OPERATORS  \
# 0                  0.86                      10.0        17.0           81.0
# 1                  1.00                       5.0         9.0           22.0
# 2                  1.00                      11.0        23.0           53.0
# 3                  0.50                       2.0         6.0           38.0
# 4                  1.00                       3.0         9.0           33.0
#
#    NUM_UNIQUE_OPERANDS  NUM_UNIQUE_OPERATORS Defective
# 0                 31.0                  21.0         1
# 1                  5.0                   8.0         0
# 2                 19.0                  19.0         1
# 3                 19.0                  13.0         1
# 4                 19.0                  14.0         1

# %%
x = df.drop(['Defective'],axis = 'columns')
x.head()
# Out:
#    LOC_BLANK  CYCLOMATIC_DENSITY  DECISION_COUNT  DECISION_DENSITY  \
# 0       16.0                0.24             8.0               2.5
# 1        2.0                0.29             4.0               2.5
# 2        1.0                0.37            10.0               2.2
# 3        8.0                0.14             2.0               2.0
# 4        1.0                0.15             2.0               3.0
#
#    DESIGN_DENSITY  EDGE_COUNT  ESSENTIAL_COMPLEXITY  LOC_EXECUTABLE  \
# 0            0.43        22.0                   6.0            23.0
# 1            0.25        11.0                   4.0            14.0
# 2            0.57        28.0                   7.0            19.0
# 3            1.00         6.0                   1.0            14.0
# 4            0.67        10.0                   3.0            19.0
#
#    PARAMETER_COUNT  HALSTEAD_CONTENT  HALSTEAD_DIFFICULTY  HALSTEAD_LENGTH  \
# 0              0.0             36.88                23.03            149.0
# 1              0.0             15.93                 7.20             31.0
# 2              1.0             25.13                19.00             91.0
# 3              1.0             31.97                10.95             70.0
# 4              1.0             30.43                 9.95             60.0
#
#    MAINTENANCE_SEVERITY  MULTIPLE_CONDITION_COUNT  NODE_COUNT  NUM_OPERATORS  \
# 0                  0.86                      10.0        17.0           81.0
# 1                  1.00                       5.0         9.0           22.0
# 2                  1.00                      11.0        23.0           53.0
# 3                  0.50                       2.0         6.0           38.0
# 4                  1.00                       3.0         9.0           33.0
#
#    NUM_UNIQUE_OPERANDS  NUM_UNIQUE_OPERATORS
# 0                 31.0                  21.0
# 1                  5.0                   8.0
# 2                 19.0                  19.0
# 3                 19.0                  13.0
# 4                 19.0                  14.0

# %%
from sklearn.cluster import KMeans

kmeans_model = KMeans(n_clusters = 2)
kmeans_model.fit(x)

kmeans_prediction = kmeans_model.predict(x)
x['cluster'] = kmeans_prediction

kmeans_prediction[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
def ASFM(DataFrame):
    SFM = 0
    
    x,y = DataFrame.shape
    
    for i in range(x):
        for j in range(y-1):
            SFM += DataFrame.iloc[i,j]
    
    return SFM/x

# %%
df0 = x[x.cluster==0]
df1 = x[x.cluster==1]

# %%
ASFM0 = ASFM(df0)
ASFM1 = ASFM(df1)

print(f"ASFM0 : {ASFM0}")
print(f"ASFM1 : {ASFM1}")
# Out:
# ASFM0 : 440.2312942271893
# ASFM1 : 13632.54333333333

# %%
#ASFM0 value is greater than ASFM1, so label 0 will represent defected software and 1 represents non-defected 
#software



TP = 0
FN = 0
TN = 0
FP = 0

n,m = df.shape

for i in range(n):
    
    defect = df.iloc[i,m-1]
    buggy = 0
    clean = 1
    
    if defect == buggy and kmeans_prediction[i]==1:
        TP += 1
    elif defect == buggy and kmeans_prediction[i]==0:
        FN += 1
    elif defect == clean and kmeans_prediction[i]==0:
        TN += 1
    else:
        FP += 1

# %%
print(TP)


#Matthew Correlation Coefficient

MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
accuracy = (TP+TN)/len(df)
# precision = TP/(TP+FP)
# recall = TP/(TP+FN)
#F1-Score
# F = 2*(precision*recall)/(precision+recall)

print(f"MCC : {MCC}")
print(f"Accuracy : {accuracy}")
print(f"precison : {precision}")
print(f"Recall : {recall}")
print(f"F1-Score : {F}")
# Out:
# 0
# MCC : -0.019923013970287985
# Accuracy : 0.872794800371402
# precison : 0.0
# Recall : 0.0
# F1-Score : 0.22672064777327935

# %% [markdown]
# # mbm

# %%
from sklearn.cluster import MiniBatchKMeans

miniBatchKmeans_model = MiniBatchKMeans(n_clusters = 2)

x = x.drop(['cluster'],axis = 'columns')
miniBatchKmeans_model.fit(x)
miniBatchKmeans_prediction = miniBatchKmeans_model.labels_
x['cluster'] = miniBatchKmeans_prediction

miniBatchKmeans_prediction[:5]
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1043: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(
# array([0, 0, 0, 0, 0])

# %%
df0 = x[x.cluster==0]
df1 = x[x.cluster==1]

ASFM0 = ASFM(df0)
ASFM1 = ASFM(df1)

print(f"ASFM0 : {ASFM0}")
print(f"ASFM1 : {ASFM1}")
# Out:
# ASFM0 : 305.4471680497934
# ASFM1 : 1940.3094690265484

# %%
#ASFM1 value is greater than ASFM0, so label 1 will represent defected software and 0 represents non-defected 
#software



TP = 0
FN = 0
TN = 0
FP = 0

n,m = df.shape


for i in range(n):
    
    defect = df.iloc[i,m-1]
    buggy = 0
    clean = 1
    
    if defect == buggy and miniBatchKmeans_prediction[i]==1:
        TP += 1
    elif defect == buggy and miniBatchKmeans_prediction[i]==0:
        FN += 1
    elif defect == clean and miniBatchKmeans_prediction[i]==0:
        TN += 1
    else:
        FP += 1

# %%
print(TP)
#Matthew Correlation Coefficient

MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
accuracy = (TP+TN)/len(df)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
#F1-Score
F = 2*(precision*recall)/(precision+recall)

print(f"MCC : {MCC}")
print(f"Accuracy : {accuracy}")
print(f"precison : {precision}")
print(f"Recall : {recall}")
print(f"F1-Score : {F}")
# Out:
# 28
# MCC : 0.1279706651529272
# Accuracy : 0.8226555246053854
# precison : 0.24778761061946902
# Recall : 0.208955223880597
# F1-Score : 0.22672064777327935

# %% [markdown]
# # ahc

# %%
from sklearn.cluster import AgglomerativeClustering

ag_model = AgglomerativeClustering(n_clusters = 2)

x = x.drop(['cluster'],axis = 'columns')
ag_model.fit(x)
ag_prediction = ag_model.labels_
x['cluster'] = ag_prediction

ag_prediction[:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)

# %%
df0 = x[x.cluster==0]
df1 = x[x.cluster==1]

# %%
ASFM0 = ASFM(df0)
ASFM1 = ASFM(df1)

print(f"ASFM0 : {ASFM0}")
print(f"ASFM1 : {ASFM1}")
# Out:
# ASFM0 : 440.2312942271893
# ASFM1 : 13632.54333333333

# %%
#ASFM0 value is greater than ASFM1, so label 0 will represent defected software and 1 represents non-defected 
#software



TP = 0
FN = 0
TN = 0
FP = 0

n,m = df.shape


for i in range(n):
    
    defect = df.iloc[i,m-1]
    buggy = 0
    clean = 1
    
    if defect == buggy and ag_prediction[i]==1:
        TP += 1
    elif defect == buggy and ag_prediction[i]==0:
        FN += 1
    elif defect == clean and ag_prediction[i]==0:
        TN += 1
    else:
        FP += 1

# %%
print(TP)
#Matthew Correlation Coefficient

MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
accuracy = (TP+TN)/len(df)
# precision = TP/(TP+FP)
# recall = TP/(TP+FN)
#F1-Score
# F = 2*(precision*recall)/(precision+recall)

print(f"MCC : {MCC}")
print(f"Accuracy : {accuracy}")
print(f"precison : {precision}")
print(f"Recall : {recall}")
print(f"F1-Score : {F}")
# Out:
# 0
# MCC : -0.019923013970287985
# Accuracy : 0.872794800371402
# precison : 0.0
# Recall : 0.0
# F1-Score : 0.22672064777327935

# %% [markdown]
# # birch

# %%
from sklearn.cluster import Birch

birch_model = Birch(threshold=0.01, n_clusters=2)

x = x.drop(['cluster'],axis = 'columns')
birch_model.fit(x)
birch_prediction = birch_model.labels_
x['cluster'] = birch_prediction

birch_prediction[:5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3384/3006890139.py in <module>
#       3 birch_model = Birch(threshold=0.01, n_clusters=2)
#       4
# ----> 5 x = x.drop(['cluster'],axis = 'columns')
#       6 birch_model.fit(x)
#       7 birch_prediction = birch_model.labels_
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['cluster'] not found in axis"

# %%
df0 = x[x.cluster==0]
df1 = x[x.cluster==1]

ASFM0 = ASFM(df0)
ASFM1 = ASFM(df1)

print(f"ASFM0 : {ASFM0}")
print(f"ASFM1 : {ASFM1}")
# Out:
# ASFM0 : 440.2312942271893
# ASFM1 : 13632.54333333333

# %%
#ASFM0 value is greater than ASFM1, so label 0 will represent defected software and 1 represents non-defected 
#software



TP = 0
FN = 0
TN = 0
FP = 0

n,m = df.shape


for i in range(n):
    
    defect = df.iloc[i,m-1]
    buggy = 0
    clean = 1
    
    if defect == buggy and birch_prediction[i]==1:
        TP += 1
    elif defect == buggy and birch_prediction[i]==0:
        FN += 1
    elif defect == clean and birch_prediction[i]==0:
        TN += 1
    else:
        FP += 1

# %%
#Matthew Correlation Coefficient

MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
accuracy = (TP+TN)/len(df)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
#F1-Score
# F = 2*(precision*recall)/(precision+recall)

print(f"MCC : {MCC}")
print(f"Accuracy : {accuracy}")
print(f"precison : {precision}")
print(f"Recall : {recall}")
print(f"F1-Score : {F}")
# Out:
# MCC : -0.019923013970287985
# Accuracy : 0.872794800371402
# precison : 0.0
# Recall : 0.0
# F1-Score : 0.22672064777327935

# %% [markdown]
# # sc

# %%
from sklearn.cluster import SpectralClustering

SC_model = SpectralClustering(n_clusters = 2)

x = x.drop(['cluster'],axis = 'columns')
SC_model.fit(x)

SC_prediction = SC_model.labels_
x['cluster'] = SC_prediction

SC_prediction[:5]
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:260: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3384/3308770516.py in <module>
#       4
#       5 x = x.drop(['cluster'],axis = 'columns')
# ----> 6 SC_model.fit(x)
#       7
#       8 SC_prediction = SC_model.labels_
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py in fit(self, X, y)
#     620
#     621         random_state = check_random_state(self.random_state)
# --> 622         self.labels_ = spectral_clustering(
#     623             self.affinity_matrix_,
#     624             n_clusters=self.n_clusters,
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py in spectral_clustering(affinity, n_clusters, n_components, eigen_solver, random_state, n_init, eigen_tol, assign_labels, verbose)
#     298     # and should be kept for spectral clustering (drop_first = False)
#     299     # See spectral_embedding documentation.
# --> 300     maps = spectral_embedding(
#     301         affinity,
#     302         n_components=n_components,
#
# ~\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first)
#     297             laplacian *= -1
#     298             v0 = _init_arpack_v0(laplacian.shape[0], random_state)
# --> 299             _, diffusion_map = eigsh(
#     300                 laplacian, k=n_components, sigma=1.0, which="LM", tol=eigen_tol, v0=v0
#     301             )
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1688     with _ARPACK_LOCK:
#    1689         while not params.converged:
# -> 1690             params.iterate()
#    1691
#    1692         return params.extract(return_eigenvectors)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in iterate(self)
#     557             else:
#     558                 Bxslice = slice(self.ipntr[2] - 1, self.ipntr[2] - 1 + self.n)
# --> 559                 self.workd[yslice] = self.OPa(self.workd[Bxslice])
#     560         elif self.ido == 2:
#     561             self.workd[yslice] = self.B(self.workd[xslice])
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\interface.py in matvec(self, x)
#     230             raise ValueError('dimension mismatch')
#     231
# --> 232         y = self._matvec(x)
#     233
#     234         if isinstance(x, np.matrix):
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in _matvec(self, x)
#     939
#     940     def _matvec(self, x):
# --> 941         return lu_solve(self.M_lu, x)
#     942
#     943
#
# ~\anaconda3\lib\site-packages\scipy\linalg\decomp_lu.py in lu_solve(lu_and_piv, b, trans, overwrite_b, check_finite)
#     142
#     143     getrs, = get_lapack_funcs(('getrs',), (lu, b1))
# --> 144     x, info = getrs(lu, piv, b1, trans=trans, overwrite_b=overwrite_b)
#     145     if info == 0:
#     146         return x
#
# KeyboardInterrupt:

# %%
df0 = x[x.cluster==0]
df1 = x[x.cluster==1]

# %%
ASFM0 = ASFM(df0)
ASFM1 = ASFM(df1)

print(f"ASFM0 : {ASFM0}")
print(f"ASFM1 : {ASFM1}")
# Out:
# ASFM0 : 145.67382113821157
# ASFM1 : 490.62499999999994

# %%
#ASFM1 value is greater than ASFM0, so label 1 will represent defected software and 0 represents non-defected 
#software



TP = 0
FN = 0
TN = 0
FP = 0

n,m = df.shape


for i in range(n):
    
    defect = df.iloc[i,m-1]
    buggy = 0
    clean = 1
    
    if defect == buggy and SC_prediction[i]==1:
        TP += 1
    elif defect == buggy and SC_prediction[i]==0:
        FN += 1
    elif defect == clean and SC_prediction[i]==0:
        TN += 1
    else:
        FP += 1

# %%
#Matthew Correlation Coefficient

MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
accuracy = (TP+TN)/len(df)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
#F1-Score
F = 2*(precision*recall)/(precision+recall)

print(f"MCC : {MCC}")
print(f"Accuracy : {accuracy}")
print(f"precison : {precision}")
print(f"Recall : {recall}")
print(f"F1-Score : {F}")
# Out:
# MCC : 0.0395153035833685
# Accuracy : 0.648
# precison : 0.5
# Recall : 0.022727272727272728
# F1-Score : 0.04347826086956522

# %% [markdown]
# # guassian

# %%
from sklearn.mixture import GaussianMixture

gm_model = GaussianMixture(n_components = 2)

x = x.drop(['cluster'],axis = 'columns')
gm_model.fit(x)
gm_prediction = gm_model.predict(x)
x['cluster'] = gm_prediction

gm_prediction[:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)

# %%
df0 = x[x.cluster==0]
df1 = x[x.cluster==1]

# %%
ASFM0 = ASFM(df0)
ASFM1 = ASFM(df1)

print(f"ASFM0 : {ASFM0}")
print(f"ASFM1 : {ASFM1}")
# Out:
# ASFM0 : 447.4803255813966
# ASFM1 : 16332.344999999998

# %%
#ASFM1 value is greater than ASFM0, so label 1 will represent defected software and 0 represents non-defected 
#software



TP = 0
FN = 0
TN = 0
FP = 0

n,m = df.shape


for i in range(n):
    
    defect = df.iloc[i,m-1]
    buggy = 0
    clean = 1
    
    if defect == buggy and gm_prediction[i]==1:
        TP += 1
    elif defect == buggy and gm_prediction[i]==0:
        FN += 1
    elif defect == clean and gm_prediction[i]==0:
        TN += 1
    else:
        FP += 1

# %%
#Matthew Correlation Coefficient

MCC = (TP*TN-FP*FN)/math.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
accuracy = (TP+TN)/len(df)
precision = TP/(TP+FP)
recall = TP/(TP+FN)
#F1-Score
# F = 2*(precision*recall)/(precision+recall)

print(f"MCC : {MCC}")
print(f"Accuracy : {accuracy}")
print(f"precison : {precision}")
print(f"Recall : {recall}")
print(f"F1-Score : {F}")
# Out:
# MCC : -0.01625950494777626
# Accuracy : 0.8737233054781801
# precison : 0.0
# Recall : 0.0
# F1-Score : 0.22672064777327935
